# %% [markdown]
# <a href="https://colab.research.google.com/github/LuxEmma/ASIM-PPI/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/LuxEmma/ASIM-PPI/refs/heads/main/data/EGFR/results1/replicate_summary.csv?token=GHSAT0AAAAAADQE6YGOUEXCDPWIBZUOVCEY2JRS7XQ"
df = pd.read_csv(url)
df.head()
# Out:
#                     name  replicate            kd           kon      koff  \
# 0         Cetuximab_scFv          1  3.332385e-09  1.514751e+06  0.005048
# 1         Cetuximab_scFv          2  9.944305e-09  3.814592e+05  0.003793
# 2  Razora712-sequence_10          1           NaN           NaN       NaN
# 3  Razora712-sequence_10          2           NaN           NaN       NaN
# 4   Razora712-sequence_2          1           NaN           NaN       NaN
#
#   binding confidence expression nc_adjusted_expression
# 0    True       high        low                    low
# 1    True       high        low                    low
# 2   False        low       high                   high
# 3   False        low       high                   high
# 4   False        low       high                   high
